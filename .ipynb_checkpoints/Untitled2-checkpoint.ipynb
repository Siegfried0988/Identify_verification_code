# %%
from PIL import Image
Image.open('captua.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=128x46 at 0x996FE50>

# %%
import cv2
img = cv2.imread('captcha.jpg')

# %%
dst = cv2.fastNlMeansDenoisingColored(img, None, 30, 30 , 7 , 21)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-25-9b92f4b8abfa> in <module>()
# ----> 1 dst = cv2.fastNlMeansDenoisingColored(img, None, 30, 30 , 7 , 21)
#
# error: ..\..\..\modules\photo\src\denoising.cpp:176: error: (-5) Type of input image should be CV_8UC3 or CV_8UC4! in function cv::fastNlMeansDenoisingColored

# %%
import matplotlib.pyplot as plt
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(dst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-32c5811df118> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 plt.subplot(121)
# ----> 3 plt.imshow(img)
#       4 plt.subplot(122)
#       5 plt.imshow(dst)
#
# C:\Users\USER\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3208                         filternorm=filternorm, filterrad=filterrad,
#    3209                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3210                         **kwargs)
#    3211     finally:
#    3212         ax._hold = washold
#
# C:\Users\USER\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\Users\USER\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5499                               resample=resample, **kwargs)
#    5500
# -> 5501         im.set_data(X)
#    5502         im.set_alpha(alpha)
#    5503         if im.get_clip_path() is None:
#
# C:\Users\USER\Anaconda2\lib\site-packages\matplotlib\image.pyc in set_data(self, A)
#     648         if (self._A.dtype != np.uint8 and
#     649                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 650             raise TypeError("Image data cannot be converted to float")
#     651
#     652         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float

# %%
plt.show()

# %%
ret,thresh = cv2.threshold(dst,127,255,cv2.THRESH_BINARY_INV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-b47b90f32426> in <module>()
# ----> 1 ret,thresh = cv2.threshold(dst,127,255,cv2.THRESH_BINARY_INV)
#
# NameError: name 'dst' is not defined
